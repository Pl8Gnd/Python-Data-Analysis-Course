# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')


joined = ratings.merge(movies, on='movieId', how='outer')
#len(ratings) == len(joined)
joined
# Out:
#         userId  movieId  rating     timestamp  \
# 0          1.0        1     4.0  9.649827e+08
# 1          5.0        1     4.0  8.474350e+08
# 2          7.0        1     4.5  1.106636e+09
# 3         15.0        1     2.5  1.510578e+09
# 4         17.0        1     4.5  1.305696e+09
# ...        ...      ...     ...           ...
# 100849     NaN    30892     NaN           NaN
# 100850     NaN    32160     NaN           NaN
# 100851     NaN    32371     NaN           NaN
# 100852     NaN    34482     NaN           NaN
# 100853     NaN    85565     NaN           NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                         Toy Story (1995)
# 2                         Toy Story (1995)
# 3                         Toy Story (1995)
# 4                         Toy Story (1995)
# ...                                    ...
# 100849  In the Realms of the Unreal (2004)
# 100850            Twentieth Century (1934)
# ...

# %%
test = pd.read_csv('ratings_example.txt', sep = '\t')
test2 = pd.read_csv('movies_example.txt', sep = '\t')
test2.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
test.merge(test2, on = 'movieId', how = 'left')

items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)
merged =  items_df.merge(purchase_df, on ='item_id', how = 'outer')
sold = merged['all sold'] = merged['stock_count'] * merged['price']

merged.assign().sort_values('all sold', ascending=False)
merged['all sold'].sum()

# %%
import os
files = os.listdir()
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
data = [i for i in files if "txt" in i]
data

# %%
import os
# os.chdir('/Users/admin/opt/Docs/B3/data')
files = os.listdir()
data = pd.concat([pd.read_csv(i) for i in files])
data
# Out:
#         1      31  2.5    1260759144  597  2664  5.0  940707473  70  1367  \
# 0     1.0  1029.0  3.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 1     1.0  1061.0  3.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 2     1.0  1129.0  2.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 3     1.0  1172.0  4.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 4     1.0  1263.0  2.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# ...   ...     ...  ...           ...  ...   ...  ...        ...  ..   ...
# 9994  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9995  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9996  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9997  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9998  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
#
#       ...  8636  1417930892  483  1573  2.0  1465387568    547    8499  1.5  \
# ...

# %%
import os
import glob
import pandas as pd
#set working directory
os.chdir("/Users/admin/opt/Docs/B3/data")

#find all csv files in the folder
#use glob pattern matching -> extension = 'csv'
#save result in list -> all_filenames
extension = 'txt'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#print(all_filenames)

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
# combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

combined_csv
# Out:
#         1      31  2.5    1260759144  597  2664  5.0  940707473  70  1367  \
# 0     1.0  1029.0  3.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 1     1.0  1061.0  3.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 2     1.0  1129.0  2.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 3     1.0  1172.0  4.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# 4     1.0  1263.0  2.0  1.260759e+09  NaN   NaN  NaN        NaN NaN   NaN
# ...   ...     ...  ...           ...  ...   ...  ...        ...  ..   ...
# 9994  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9995  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9996  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9997  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
# 9998  NaN     NaN  NaN           NaN  NaN   NaN  NaN        NaN NaN   NaN
#
#       ...  8636  1417930892  483  1573  2.0  1465387568    547    8499  1.5  \
# ...

# %%
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %%
import os
files = os.listdir('data')
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
temp = pd.read_csv( os.path.join('data', 'ratings_10.txt'), names = ['userId', 'movieId', 'rating', 'timestamp'] )
data = pd.concat([data, temp])
data


9999+80000+10005
# Out:
# 100004
