# %%
import pandas as pd
df = pd.read_csv('data_sf.csv') 
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
s = df['Position'].value_counts(normalize=True)

s.loc[s<0.01]

s = df['Wage'].value_counts(bins=4)
a = df[(df['Wage'] > s.index[0].left) & (df['Wage'] <= s.index[0].right)]
#a['Nationality'].value_counts(normalize=True)
a[(a.Nationality == 'Spain')].count()

s = df[(df.Club =='Manchester United')]['Nationality'].unique()
len(s)

s = df[(df.Nationality == 'Spain')]['Wage'].value_counts(bins=4, normalize=True)

int(round( s[s.index.left==s.index.left.min()].iloc[0] * 100 ))

# %%
import pandas as pd
df = pd.read_csv('data_sf.csv') 
s = df[(df.Club =='Manchester United')]['Nationality'].unique()
len(s)

s = small_df['Nationality'].value_counts()
s_df = s.reset_index()
s_df.columns = ['Nationality','Players Count']

s = df[(df.Nationality  == 'Brazil') & (df.Club == 'Juventus')]['Name'].unique()
list(s)

s = df[(df.Club == 'Manchester United')]['Nationality'].unique()
len(s)

# %%
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
grouped_df
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)

df[df.Nationality == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]

s = df.groupby(['Club'])['Wage'].agg(['median', 'mean']).sort_values(['median'],ascending=False)
s[(s['mean'] == s['median'])].max()
s.loc[s['mean'] ==13000]

s = df.groupby(df['Nationality'])[['Strength', 'Balance']].max().sort_values(['Strength'],ascending=False)
s.loc["Argentina"]

s = df[df.Nationality == "Argentina"][['Name','Club','Wage','Balance','Strength']]
s[(s.Club == "FC Barcelona")].max()

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],                                                                                            
aggfunc='sum',
margins=True,
fill_value=0)
pivot

s = df.pivot_table(columns = 'Position', index = 'Club'   , values = 'Name', aggfunc = 'count',
fill_value=0)
s.GK.mean()

# %%
s = df.loc[df['Club'].isin(['AS Monaco','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],                                                                                            
aggfunc='sum',
fill_value=0)
s
# Out:
#                         Wage
# Club               AS Monaco Juventus Manchester United Real Madrid
# Nationality
# Argentina                  0   205000            206000           0
# Belgium                47000        0            230000      240000
# Bosnia Herzegovina         0   180000                 0           0
# Brazil                 55000   335000             91000      570000
# Chile                      0        0            215000           0
# Colombia              115000        0                 0           0
# Costa Rica                 0        0                 0      195000
# Croatia                70000   160000                 0      420000
# Dominican Republic         0        0                 0      140000
# Ecuador                    0        0            120000           0
# England                    0        0            478000           0
# France                 95000   145000            375000      459000
# ...

# %%
s = df.pivot_table(columns = 'Position', index = 'Club', values = 'SprintSpeed', aggfunc = 'mean',
fill_value=0)
s[(s.ST>70)].sort_values('ST',ascending=False).head(13)

s = df.groupby(['Position'])['SprintSpeed'].mean().sort_values(ascending=False).head(15)
s
# Out:
# Position                 CAM         CB   CDM   CF    CM         GK  LAM  \
# Club
# Vitória            70.666667  56.000000  64.0  0.0   0.0  42.500000    0
# Sydney FC          79.500000  59.000000   0.0  0.0  64.5  44.666667    0
# CD Lugo            72.000000  48.500000  50.0  0.0  56.0  44.500000    0
# Brøndby IF         74.000000  68.000000  65.0  0.0  65.5  38.000000    0
# Leicester City     74.000000  57.000000   0.0  0.0  57.0  60.000000    0
# Manchester United   0.000000  69.200000  59.0  0.0  64.5  51.000000    0
# Feyenoord           0.000000  71.500000   0.0  0.0  67.0  33.500000    0
# FC Zürich           0.000000  59.333333  73.0  0.0  65.6  43.000000    0
# KRC Genk           57.000000  68.000000  60.0  0.0   0.0  46.500000    0
# FC Bayern München  68.500000  68.666667  53.0  0.0  70.6  37.500000   67
# Gillingham         81.333333  59.000000  70.0  0.0  68.5  32.000000    0
# FC Porto            0.000000  73.000000  68.0  0.0  74.0  39.000000    0
# ...
